# %% [markdown]
# # Taller
#
# En este taller vamos a estar trabajando con dos conjuntos de datos que nos van a permitir aplicar todos los conocimiento aprendidos hasta ahora.
# * `application_record_final.csv`: es un archivo que contiene las características de las personas al momento de hacer la solicitud de su crédito.
# * `default_mark_dataset.csv`: contiene la información de si la persona tuvo un crédito aprobado si el mismo presentó algún incumplimiento en su pago.
#
# Si quieren conocer más información acerca de las variables que componen los conjuntos de datos pueden revisar este [link](https://www.kaggle.com/datasets/rikdifos/credit-card-approval-prediction).
#
# #### **Se aclara que el conjunto de datos previamente ha sido parcialmente procesado para el uso en este taller.**
#
# Estos son los pasos propuestos para el taller:
#
# 1. Leer conjuntos de datos.
# 2. Unificar conjuntos de datos.
# 3. Realizar un análisis exploratorio básico tomando en consideración la variable `default`.
# 4. Realizar preprocesamiento necesario.
# 5. Dividir conjunto de datos en train y test.
# 6. (Opcional) Escalar datos.
# 7. Entrenar 2 o más modelos.
# 8. Predecir y generar métricas.
# 9. Optimizar hiperparámetros de los modelos que deseen (con 1 solo es suficiente).
# 10. Predecir y generar métricas finales.
# 11. (Opcional) Generar importancia de características.

# %%
## Librerías
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
# Funciones para generar una matriz de confusión y reporte con métricas para clasificadores
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
# Función para gráficar la importancia de variables
from yellowbrick.model_selection import feature_importances
# Modulo para arboles de clasificación
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost
import lightgbm
